# %%
import pandas as pd
import numpy as np
import json

# %%
data = json.load(open("data/test.json"))

# %%
data
# Out:
# {'filters': {'is_most_stable_site': True,
#   'bulk_surface_property_set.is_stretched': False,
#   'bulk_surface_property_set.is_compressed': False,
#   'adsorbate_fraction.numeric': {'$gte': 0, '$lte': 0.34}},
#  'results': [{'ph2': 0.711,
#    'pch4': 0.222,
#    'pco2': 0.178,
#    'co2_whsv': 9.076,
#    'reaction_temp': 350,
#    'ch4_production': 1.58,
#    'catalytic_metal': 'Ni',
#    'ch4_selectivity': 94.14,
#    'support_material': 'Al2O3',
#    'pretreatment_temp': 500,
#    'experiment_start_date': '2023-09-15',
#    'total_reaction_pressure': 1.193,
#    'nominal_metal_weight_loading': 3,
#    'id': 301},
#   {'ph2': 2.561,
#    'pch4': 0.222,
#    'pco2': 0.64,
#    'co2_whsv': 9.076,
#    'reaction_temp': 350,
#    'ch4_production': 2.226,
#    'catalytic_metal': 'Ni',
#    'ch4_selectivity': 99.58,
#    'support_material': 'Al2O3',
#    'pretreatment_temp': 500,
#    'experiment_start_date': '2023-09-15',
#    'total_reaction_pressure': 4.297,
# ...

# %%
df = pd.DataFrame(data['results'])

# %%
df
# Out:
#       ph2   pch4   pco2  co2_whsv  reaction_temp  ch4_production  \
# 0   0.711  0.222  0.178     9.076            350           1.580
# 1   2.561  0.222  0.640     9.076            350           2.226
# 2   4.082  0.222  1.020     9.076            350           2.473
# 3   0.718  0.214  0.179     9.041            250           0.103
# 4   0.718  0.214  0.179     9.041            300           0.336
# 5   0.718  0.214  0.179     9.041            350           0.969
# 6   0.715  0.217  0.179     9.077            250           0.033
# 7   0.715  0.217  0.179     9.077            300           0.249
# 8   0.715  0.217  0.179     9.077            350           0.799
# 9   0.716  0.216  0.179     9.064            250           0.082
# 10  0.716  0.216  0.179     9.064            300           0.362
# 11  0.716  0.216  0.179     9.064            350           1.089
# 12  0.708  0.225  0.177     0.904            300           0.252
# ...
